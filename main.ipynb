# %%
import os
os.chdir('/content/drive/MyDrive/SeqGenerationwithTransformers')
import torch
import torch.nn as nn
from torch.nn import functional as F
from vocabulary import vocab
from hyperparameters import *
from dataLoader import *
from Transformer import LanguageModel
from train import *

torch.manual_seed(seed)

# Read file
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

vocab_size, data = vocab(text)

# Split the dataset
n = int(0.9*len(data))
train_data = data[:n] # 90% is train data
val_data = data[n:]   # 10% validation data

'''
model = LanguageModel(vocab_size).to(device) # Instantiate the model object

train(model, train_data, val_data)
torch.save(model, 'model.pt')
'''
# Out:
# step 0: train loss 4.3257, val loss 4.3274
# step 500: train loss 2.2190, val loss 2.2518
# step 1000: train loss 1.8383, val loss 1.9722
# step 1500: train loss 1.6347, val loss 1.7973
# step 2000: train loss 1.5155, val loss 1.7057
# step 2500: train loss 1.4368, val loss 1.6392
# step 3000: train loss 1.3836, val loss 1.5925
# step 3500: train loss 1.3412, val loss 1.5657
# step 4000: train loss 1.3040, val loss 1.5374
# step 4500: train loss 1.2764, val loss 1.5223
# step 5000: train loss 1.2519, val loss 1.5127
# step 5500: train loss 1.2310, val loss 1.5007
# step 6000: train loss 1.2113, val loss 1.4960
# step 6500: train loss 1.1890, val loss 1.4926
# step 7000: train loss 1.1709, val loss 1.4836
# step 7500: train loss 1.1570, val loss 1.4914

# %%
import os
os.chdir('/content/drive/MyDrive/SeqGenerationwithTransformers')
import torch
from decoder import decode
from hyperparameters import device

model = torch.load('model.pt')
model.eval()

# Generate a sequence from the model
max_new_tokens = 5000
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(model.generate(context, max_new_tokens)[0].tolist()))
# Out:
#  York i' the enjoy; and I will falcous.
#
# LEONTES:
# Thousand either thoughts.
#
# Nurse:
# I tell thee, I presently nobles.
#
# First Musician;
# Poor partnical:
# Fear I am a pause, gobey.
#
# ESCALUS:
# Why, you fear?
#
# ESCALUS:
# Well pould you child her?
#
# ELBOW:
# Uncle?--Go to be! A goodle: enforced, why about them?
#
# ELBOW:
# My lord, what uncle, who have can been for me? I have saught
# you!
#
# ESCALUS:
# O sweetest are gone the need little resolve!
#
# POMPEY:
# It was your mother deserves to remembrance you
# and good Corioli and eggant the easy to France,
# Your mind own bodies
# I thank you. This in Antonio's noble day,
# And made be so peril to benefit him that,
# Gloang me too holy in's bloody; not lay despeak.
#
# JULIET:
# What need from him made all shadow me ne'er before
# I shoot to do not, as so your love high about
# His comfort eyes so privy on such faults
# From the was.
#
# Nurse:
# Welcome, pape, peace!
#
# Nurse:
# He had he forthward to beat you, sir.
#
# ROMEO:
# This is desire as very fall
# his pinch stones are functived where it might
# That he you swools reside membs, that his news
# Is letter than leave your brother will triumph.
#
# ROMEO:
# No read it.
#
# JULIET:
# O letter him, midstress, being his honour's maid!
# When God's throyal that makes a hoider friends,
# That you never lie him to some be thus your vow
# No cause that you may see your swords: yea, give
# No lend Henry, and men the Duke of Gloucester,
# The just of the Lord Hastings, hath been too;
# For the villain were it was full of your scape--
#
# KING RICHARD II:
# Marry, Lord Hastings, herein till I not saw,
# And comes her by Tybalt is princely I plegent:
# And, away, a man of the heavy winds,
# And sent these holds seeming and the horse
# That he in judge?
#
# SCALUS:
# Ay 'scome ill as I have to paint our tongs
# That you are?
#
# LEONTES:
# This deciving'st?
# Did stand I not say; I draw not
# The true: but that's like person.
#
# POLIXENES:
# What, in this, then?
#
# ABHORSON:
# O young Master's other?
#
# ESCALUS:
#
# JULIET:
# I am music; and who imputed the instruction
# For his portective in a mony.
#
# LEONTES:
# I am infush'd; but he will woe to the sacraments
# Of that mark him: it is at home.
#
# POMPEY:
# Prithee, sir; when she's ha best must do,
# Or she is a sister where, Romeo, as he will?
#
# HENRY BOLINGBROKE:
# A needed more, a subject he losed for sir;
# I have Berkeley, my lady, nay, my God
# Richard husband; and in Richard; Burgundy, help,
# How lies in the despatch'd of king. Come, came hither;
# As she will fill the want from her course.
#
# Shepherd:
# It is it strange to be strong from a lowful sweet,
# And give patheth him born as other lovedship.
# How now, by my sins me but as you, my lord?
#
# DUKE VINCENTIO:
# A heart nor bare some of another father,
# Than thou oft tyrant is.
#
# LUCENTIO:
# There is before so have, need in thy defence.
#
# HORTENSIO:
# Good mother, kiss of it?
#
# DUKE VINCENTIO:
# So you tent this, who have your fault is you lived?
#
# ESCALUS:
# The next are better than me the son's fave,
# And thou art such a fool, save army.
#
# LUCIO:
# Thou, shalt help; the poor Publis of this walls:
# 'Tis a place, excunt made thy old and man!
# If I be king, thou hast no more as, that, to fight,
# I was a born cold, thou shalt robb the power.
# Therefore, go up your good princely hath still'd cervied
# By fear's friends, the great, and the tidings was bethrow
# That I may give.
#
# LUCIO:
# 'Tis no use our peace, by sake: I should undertake
# The queen of the greatings has groaty'd for Rutland.
#
# TYBALT:
# Were I go not when probach more in your differing?
#
# Second Citizen:
# Nay, go.
#
# PETRUCHIO:
# Thy son when thou hast been undone rest,
# piece is out possible: yet it is
# To banished.
#
# BRUTUS:
# Not another,
# I'll be slew it, eyester repent you would not sleep
# Thy summer was love is spirit!
#
# CAPULET:
# I do not, come to your wratches?
#
# SAMPSON:
# True! Doth your gracious black! A regian would
# To speak follow, and profation of your son. But, I am
# I power your grace unto me;
# But whether you shall pawn your dear to arm
# As I should shake you in a man noble villain:
# Lament and home to his secret youth you, for the hope:
# That would most might traitor shall not instruct love,
# Do put you access. As you, you are a man
# The queen that I seeu laid: yet, his good uncle, he fom your husband;
# To dry us the earth, your strange hath made me
# At any treasons. Touching a man
# I would have been a horse: doth injuries me me,
# To send of this afterous and honour way;
# Sile Prince by Aufidius, which heavens will know
# The very loing widows cury, and going it with us:
# The song provides of sullenity
# She proclimate of this was of mine honour!
# He is of from the age, Claudio, sir, we mighty be.
# The basin of God's part; and when thou namest,
# Now thou nless from his meansier part; I'll find
# Ten every matter me, or if thou didst not be silence
# And be seven in rest, yet thou to answer
# I am more who worth than a brought;
# But not sorry on the sun throng, but the face,
# I'll show it.
#
# LEONTES:
# Very well;
# A fearful o'clock was for into see me,
# That this happy of my minister's past,
# His name is the poor to break and councry'd!
#
# DUKE VINCENTIO:
# I'll not rest,
